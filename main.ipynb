# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('vehicle.csv')

# %%
df
# Out:
#                           Category                          Segment  \
# 0         Passenger Vehicles (PVs)                   Passenger Cars
# 1         Passenger Vehicles (PVs)           Multi-Utility Vehicles
# 2         Passenger Vehicles (PVs)   Total Passenger Vehicles (PVs)
# 3   Commercial Vehicles - M & HCVs               Passenger Carriers
# 4   Commercial Vehicles - M & HCVs                   Goods Carriers
# 5   Commercial Vehicles - M & HCVs                   Total M & HCVs
# 6       Commercial Vehicles - LCVs               Passenger Carriers
# 7       Commercial Vehicles - LCVs                   Goods Carriers
# 8       Commercial Vehicles - LCVs                       Total LCVs
# 9        Commercial Vehicles (CVs)  Total Commercial Vehicles (CVs)
# 10                  Three Wheelers               Passenger Carriers
# 11                  Three Wheelers                   Goods Carriers
# 12                  Three Wheelers             Total Three Wheelers
# ...

# %% [markdown]
# ## Scatter Plot Code

# %%
fig = plt.figure(figsize = (10,6))
plt.rcParams.update({'font.size': 12})
plt.scatter(df.iloc[3,:].values[2: 16], df.iloc[18,:].values[2: 16], label='Passengers')
plt.scatter(df.iloc[6,:].values[2: 16], df.iloc[18,:].values[2: 16], label='Commercial')
plt.title('Production of different kinds of Vehicles')
plt.legend(title='Type of Vehicle')
plt.xlabel('No. of Passenger Vehicles')
plt.ylabel('Total Number of Vehicles')
plt.grid()
plt.savefig('scatter plot.png')
plt.show()

# %% [markdown]
# ## Box Plot Code

# %%
years = ['2006-07', '2007-08', '2008-09', '2009-10']
temp_data = df[years][:7]
fig = plt.figure(figsize = (10,6))
plt.rcParams.update({'font.size': 12})

data_list = []
for i in range(4):
    data_list.append(temp_data.iloc[:,i].values)
plt.boxplot(data_list, labels = years, patch_artist = True)
plt.title("Vehicle Production in 4 years")
plt.xlabel('Financial Year')
plt.ylabel('Production')
plt.gca().yaxis.grid(True)
plt.savefig('box plot.png')
plt.show()

# %%
years = ['2006-07', '2007-08', '2008-09', '2009-10']
temp_data = df[years][:8]
fig = plt.figure(figsize = (10,6))
plt.rcParams.update({'font.size': 12})

data_list = []
for i in range(4):
    data_list.append(temp_data.iloc[:,i].values)
plt.boxplot(data_list, labels = years, patch_artist = True)
plt.title("Vehicle Production in 4 years")
plt.xlabel('Financial Year')
plt.ylabel('Production')
plt.gca().yaxis.grid(True)
plt.savefig('box plot outliers.png')
plt.show()

# %% [markdown]
# ## Bar Plot Code

# %%
years = ['2001-02', '2002-03', '2003-04', '2004-05', '2005-06','2006-07', '2007-08', '2008-09', '2009-10']
temp_data = df[years].iloc[18,:].values

fig = plt.figure(figsize = (10,6))
plt.rcParams.update({'font.size': 12})

plt.bar(years, temp_data)
plt.title("Vehicle Production over years")
plt.xlabel('Financial Year')
plt.ylabel('Total Production')
plt.gca().yaxis.grid(True)
plt.savefig('bar plot.png')
plt.show()
